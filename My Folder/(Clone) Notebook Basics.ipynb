# %%
print("Hello World!")

# %%
# %sql
SELECT "HELLO WORLD SQL!"

# %%
# %fs ls './databricks-datasets'

# %%
dbutils.help()

# %%
files = dbutils.fs.ls('./databricks-datasets')
print(files)

# %%
display(files)

# %%
files
